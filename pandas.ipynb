# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
g7_pop = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
g7_pop.name = "G7 Population in millions"

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
g7_pop.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %%
type(g7_pop.values)
# Out:
# numpy.ndarray

# %%
g7_pop[0]
# Out:
# 35.467

# %%
g7_pop[1]
# Out:
# 63.951

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
g7_pop.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdoms',
    'United States',
]

# %%
g7_pop
# Out:
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdoms     64.511
# United States      318.523
# Name: G7 Population in millions, dtype: float64

# %%
### we make the above series 
### directly with following method

# %%
pd.Series({
    'Canada' : 35.467,
    'france' : 63.951,
    'Germany' : 80.94,
    'Italy' : 60.665,
    'Japan' : 127.061,
    'United kingdoms' : 64.511,
    'United States' : 318.523,
}, name = 'G7 Population in millions')
# Out:
# Canada              35.467
# france              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United kingdoms     64.511
# United States      318.523
# Name: G7 Population in millions, dtype: float64

# %%
## Indexing

# %%
g7_pop
# Out:
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdoms     64.511
# United States      318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop['Canada']
# Out:
# 35.467

# %%
g7_pop.iloc[0]

# for numeric positions we use .iloc
# Out:
# 35.467

# %%
# selecting multiple elements at once

g7_pop[['Italy', 'France', 'Canada']]
# Out:
# Italy     60.665
# France    63.951
# Canada    35.467
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop[[0, 1]]
# Out:
# Canada    35.467
# France    63.951
# Name: G7 Population in millions, dtype: float64

# %%
# slicing works but upper limit also included

g7_pop['Canada' : 'Italy']
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: G7 Population in millions, dtype: float64

# %%
# Conditional Selection(boolean)

# %%
g7_pop > 70
# Out:
# Canada             False
# France             False
# Germany             True
# Italy              False
# Japan               True
# United Kingdoms    False
# United States       True
# Name: G7 Population in millions, dtype: bool

# %%
g7_pop[g7_pop > 70]
# Out:
# Germany           80.940
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
g7_pop[g7_pop > g7_pop.mean()]
# Out:
# Japan            127.061
# United States    318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.std()
# Out:
# 97.24996987121581

# %%
g7_pop[(g7_pop > g7_pop.mean() - g7_pop.std() / 2) | (g7_pop > g7_pop.mean() + g7_pop.std() / 2)]
# Out:
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdoms     64.511
# United States      318.523
# Name: G7 Population in millions, dtype: float64

# %%
# ~ not
# | or
# & and

# %%
# OPERATIONS AND METHOD

# %%
g7_pop
# Out:
# Canada              35.467
# France              63.951
# Germany             80.940
# Italy               60.665
# Japan              127.061
# United Kingdoms     64.511
# United States      318.523
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop * 1_000_000
# Out:
# Canada              35467000.0
# France              63951000.0
# Germany             80940000.0
# Italy               60665000.0
# Japan              127061000.0
# United Kingdoms     64511000.0
# United States      318523000.0
# Name: G7 Population in millions, dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30257142857144

# %%
g7_pop['France' : 'Italy'].mean()
# Out:
# 68.51866666666666

# %%
# Data frames

# %%
df=pd.read_csv('sales.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
ae=df.head(10)

# %%
ae.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
ae.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
ae.info
# Out:
# <bound method DataFrame.info of     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
ae.shape
# Out:
# (10, 17)

# %%
ae.size
# Out:
# 170

# %%
 ae.describe()
# Out:
#        Unit price   Quantity     Tax 5%       Total        cogs  \
# count   10.000000  10.000000  10.000000   10.000000   10.000000
# mean    59.972000   6.200000  19.884400  417.572400  397.688000
# std     22.594996   2.347576  11.619882  244.017528  232.397646
# min     15.280000   2.000000   3.626000   76.146000   72.520000
# 25%     48.457500   5.250000  10.223375  214.690875  204.467500
# 50%     63.530000   7.000000  21.970000  461.370000  439.400000
# 75%     74.407500   7.000000  28.950250  607.955250  579.005000
# max     86.310000  10.000000  36.780000  772.380000  735.600000
#
#        gross margin percentage  gross income     Rating
# count                10.000000     10.000000  10.000000
# mean                  4.761905     19.884400   7.080000
# std                   0.000000     11.619882   1.770624
# min                   4.761905      3.626000   4.100000
# 25%                   4.761905     10.223375   5.825000
# ...

# %%
ae.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
ae.dtypes.value_counts()
# Out:
# object     9
# float64    7
# int64      1
# dtype: int64

# %%
ae.iloc[1]
# Out:
# Invoice ID                            226-31-3081
# Branch                                          C
# City                                    Naypyitaw
# Customer type                              Normal
# Gender                                     Female
# Product line               Electronic accessories
# Unit price                                  15.28
# Quantity                                        5
# Tax 5%                                       3.82
# Total                                       80.22
# Date                                     3/8/2019
# Time                                        10:29
# Payment                                      Cash
# cogs                                         76.4
# gross margin percentage                  4.761905
# gross income                                 3.82
# Rating                                        9.6
# Name: 1, dtype: object

# %%
ae['City']
# Out:
# 0       Yangon
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# 4       Yangon
# 5    Naypyitaw
# 6       Yangon
# 7    Naypyitaw
# 8       Yangon
# 9     Mandalay
# Name: City, dtype: object

# %%
ae['City'].to_frame()
# Out:
#         City
# 0     Yangon
# 1  Naypyitaw
# 2     Yangon
# 3     Yangon
# 4     Yangon
# 5  Naypyitaw
# 6     Yangon
# 7  Naypyitaw
# 8     Yangon
# 9   Mandalay

# %%
ae[['City', 'Gender']]
# Out:
#         City  Gender
# 0     Yangon  Female
# 1  Naypyitaw  Female
# 2     Yangon    Male
# 3     Yangon    Male
# 4     Yangon    Male
# 5  Naypyitaw    Male
# 6     Yangon  Female
# 7  Naypyitaw  Female
# 8     Yangon  Female
# 9   Mandalay  Female

# %%
ae[0:3]
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  3/3/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4

# %%
ae.loc[3]
# Out:
# Invoice ID                       123-19-1176
# Branch                                     A
# City                                  Yangon
# Customer type                         Member
# Gender                                  Male
# Product line               Health and beauty
# Unit price                             58.22
# Quantity                                   8
# Tax 5%                                23.288
# Total                                489.048
# Date                               1/27/2019
# Time                                   20:33
# Payment                              Ewallet
# cogs                                  465.76
# gross margin percentage             4.761905
# gross income                          23.288
# Rating                                   8.4
# Name: 3, dtype: object

# %%
ae.loc[1:3,'City']
# Out:
# 1    Naypyitaw
# 2       Yangon
# 3       Yangon
# Name: City, dtype: object

# %%
ae.loc[1:3,['City','Gender']]
# Out:
#         City  Gender
# 1  Naypyitaw  Female
# 2     Yangon    Male
# 3     Yangon    Male

# %%
ae
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# ...

# %%
ae.iloc[0, 3,]
# Out:
# 'Member'

# %%
##boolean

# %%
ae['Rating'] > 9
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Rating, dtype: bool

# %%
ae.loc[ae['Rating'] > 9]
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total      Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200  3/8/2019
#
#     Time  Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08  Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29     Cash   76.40                 4.761905        3.8200     9.6

# %%
ae.loc[ae['Rating'] > 9 , 'Rating']
# Out:
# 0    9.1
# 1    9.6
# Name: Rating, dtype: float64

# %%
ae.loc[ae['Rating'] > 9 , ['Rating', 'Total', 'cogs']]
# Out:
#    Rating     Total    cogs
# 0     9.1  548.9715  522.83
# 1     9.6   80.2200   76.40

# %%
###Dropping stuff

# %%
ae.drop(1)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
# ...

# %%
ae.drop([7, 8])
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 5  699-14-3026      C  Naypyitaw        Normal    Male
# 6  355-53-5943      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# ...

# %%
ae.drop(columns=['City', 'cogs'])
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# ...

# %%
ae.drop(columns=['City', 'cogs'], axis=1)
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# ...

# %%
ae.drop(['City', 'cogs'], axis='columns')
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# ...

# %%
ae.drop([5, 6], axis='rows')
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
# 7  315-22-5665      C  Naypyitaw        Normal  Female
# 8  665-32-9167      A     Yangon        Member  Female
# 9  692-92-5582      B   Mandalay        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# ...

# %%
# all these methods return a new Dataframe.
#If you'd like yo modify it "in place", 
#you canuse inplace or "inplace=true" which is below

# %%
ae.drop(columns=['Total'], inplace = True)
# Out:
# C:\Users\RAHUL\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ae
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%       Date   Time      Payment  \
# 0       74.69         7  26.1415   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   3/8/2019  10:29         Cash
# ...

# %%
#operations

# %%
ae[['gross income','Rating']]
# Out:
#    gross income  Rating
# 0       26.1415     9.1
# 1        3.8200     9.6
# 2       16.2155     7.4
# 3       23.2880     8.4
# 4       30.2085     5.3
# 5       29.8865     4.1
# 6       20.6520     5.8
# 7       36.7800     8.0
# 8        3.6260     7.2
# 9        8.2260     5.9

# %%
ae[['gross income','Rating']] / 100
# Out:
#    gross income  Rating
# 0      0.261415   0.091
# 1      0.038200   0.096
# 2      0.162155   0.074
# 3      0.232880   0.084
# 4      0.302085   0.053
# 5      0.298865   0.041
# 6      0.206520   0.058
# 7      0.367800   0.080
# 8      0.036260   0.072
# 9      0.082260   0.059

# %%
# operations with series work at a column level, broadcasting down the rows(which can be counter intuitive)

# %%
crisis = pd.Series([-10, -0.3], index=['gross income','Rating'])

# %%
crisis
# Out:
# gross income   -10.0
# Rating          -0.3
# dtype: float64

# %%
ae[['gross income', 'Rating']] + crisis
# Out:
#    gross income  Rating
# 0       16.1415     8.8
# 1       -6.1800     9.3
# 2        6.2155     7.1
# 3       13.2880     8.1
# 4       20.2085     5.0
# 5       19.8865     3.8
# 6       10.6520     5.5
# 7       26.7800     7.7
# 8       -6.3740     6.9
# 9       -1.7740     5.6

# %%
# modyfying dataframes

# %%
#adding new column

# %%
ae
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%       Date   Time      Payment  \
# 0       74.69         7  26.1415   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   3/8/2019  10:29         Cash
# ...

# %%
city = pd.Series(
['dehli', 'dehradun', 'daman'],
index=['3', '5', '4'],
name='Location'
)

# %%
city
# Out:
# 3       dehli
# 5    dehradun
# 4       daman
# Name: Location, dtype: object

# %%
ae['Location'] = city
# Out:
# C:\Users\RAHUL\AppData\Local\Temp/ipykernel_5388/2061089221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ae['Location'] = city

# %%
ae
# Out:
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# 7  315-22-5665      C        Normal  Female      Home and lifestyle
# 8  665-32-9167      A        Member  Female       Health and beauty
# 9  692-92-5582      B        Member  Female      Food and beverages
#
#    Unit price  Quantity   Tax 5%       Date   Time      Payment  \
# 0       74.69         7  26.1415   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   3/8/2019  10:29         Cash
# ...

# %%
#learn again

# %%
#replacing values per column

# %%
ae['Location'] = 'India'
ae
# Out:
# C:\Users\RAHUL\AppData\Local\Temp/ipykernel_5388/3121717186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ae['Location'] = 'India'
#     Invoice ID Branch Customer type  Gender            Product line  \
# 0  750-67-8428      A        Member  Female       Health and beauty
# 1  226-31-3081      C        Normal  Female  Electronic accessories
# 2  631-41-3108      A        Normal    Male      Home and lifestyle
# 3  123-19-1176      A        Member    Male       Health and beauty
# 4  373-73-7910      A        Normal    Male       Sports and travel
# 5  699-14-3026      C        Normal    Male  Electronic accessories
# 6  355-53-5943      A        Member  Female  Electronic accessories
# ...

# %%
#renaming columns

# %%
ae.rename(
    columns={
        'Product line':'PL',
        'Customer type':'Cust_type'
    }, index={
         '1' : 'one',
         '2' : 'two',
        '3': 'three',
        '4': 'four',
    })
# Out:
#     Invoice ID Branch Cust_type  Gender                      PL  Unit price  \
# 0  750-67-8428      A    Member  Female       Health and beauty       74.69
# 1  226-31-3081      C    Normal  Female  Electronic accessories       15.28
# 2  631-41-3108      A    Normal    Male      Home and lifestyle       46.33
# 3  123-19-1176      A    Member    Male       Health and beauty       58.22
# 4  373-73-7910      A    Normal    Male       Sports and travel       86.31
# 5  699-14-3026      C    Normal    Male  Electronic accessories       85.39
# 6  355-53-5943      A    Member  Female  Electronic accessories       68.84
# 7  315-22-5665      C    Normal  Female      Home and lifestyle       73.56
# 8  665-32-9167      A    Member  Female       Health and beauty       36.26
# 9  692-92-5582      B    Member  Female      Food and beverages       54.84
#
#    Quantity   Tax 5%       Date   Time      Payment  gross margin percentage  \
# ...

# %%
#for character name index
#ae.rename(index=str.upper)

# %%
#ae.rename(index=lambda x: x.lower())

# %%
####adding values

# %%
### statiscal info

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
c=df['cogs']

# %%
c.min(), c.max()
# Out:
# (10.17, 993.0)

# %%
c.sum()
# Out:
# 307587.38

# %%
c.sum() / len(c)
# Out:
# 307.58738

# %%
c.mean()
# Out:
# 307.58738000000034

# %%
c.std()
# Out:
# 234.17650961997307

# %%
c.median()
# Out:
# 241.76

# %%
c.describe()
# Out:
# count    1000.00000
# mean      307.58738
# std       234.17651
# min        10.17000
# 25%       118.49750
# 50%       241.76000
# 75%       448.90500
# max       993.00000
# Name: cogs, dtype: float64

# %%
c.quantile()
# Out:
# 241.76

# %%
c.quantile(.50)
# Out:
# 241.76

# %%
c.quantile([.2, .4, .6, .8])
# Out:
# 0.2     93.084
# 0.4    185.808
# 0.6    310.216
# 0.8    507.864
# Name: cogs, dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df.index, df['Total'])
